# %%
import pandas as pd
from pandas_profiling import ProfileReport

# Load your dataset
df = pd.read_csv("../data/interim/gurgaon_properties_cleaned_v2.csv").drop_duplicates()

# Create the ProfileReport object
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)

# Generate the report
profile.to_file("../reports/output_report.html")
# Out:
# 100%|██████████| 23/23 [00:00<00:00, 54.10it/s]0<00:00, 62.61it/s, Describe variable: luxury_score]
# Summarize dataset: 100%|██████████| 133/133 [00:08<00:00, 16.06it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:03<00:00,  3.98s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.01it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 47.38it/s]
